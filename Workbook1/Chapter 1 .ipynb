# %% [markdown]
# Exercise 1
#
# Each line of code below contains an error. Fix the error and explain in a comment the reason for the error.

# %%
Print('Hello world!')

# %%
print("Hello world!")
#the P in print is wrong it must be small letter
# Out:
# Hello world!

# %%
print'Hello world!')

# %%
print("Hello world!")
#There's no parenthesis after the word print
# Out:
# Hello world!

# %%
print('Hello world!)

# %%
print("Hello world!")
#the quatation mark is double
# Out:
# Hello world!

# %% [markdown]
# Exercise 2
#
# What is the output of the code below? [PEW]

# %%
x = 43
x = x + 1
print(x)
# Out:
# 44

# %%
print ("44")
# Out:
# 44

# %% [markdown]
# Exercise 3
# The code below contains an error. Fix the error and explain in a comment the reason for the error.

# %%
x = 43
x = X + 1
print(x)

# %%
x = 43
x = x + 1
print (x)
#in second line, the letter X would be a small letter
# Out:
# 44
